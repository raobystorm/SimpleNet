# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
from SimpleNet import *

# %%
net = Network([4, 3], learn_rate=0.03, loss_func=cross_entropy_func)

# %%
net.evaluate('/Users/rui.zhong/SimpleNet/iris.data', epochs=500, batch_size=30)
# Out:
# Finished training! Start testing...
# Finished testing! The result accuracy is: 1.0
# ...
# [[  1.21200162   2.96023307  -5.75013705]
#  [  9.61038515  -1.06025688 -10.47597443]
#  [-10.35075397  -0.88868558  11.51772135]
#  [ -2.30724405  -5.20934019   7.11746361]]

# %%
plt.plot(net.train_log[::10])
