# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
from SimpleNet import *

# %%
net = Network([4, 3], learn_rate=0.03, loss_func=cross_entropy_func)

# %%
net.evaluate('/Users/rui.zhong/SimpleNet/iris.data', epochs=500, batch_size=30)
# Out:
# Finished training! Start testing...
# Finished testing! The result accuracy is: 0.9333333333333333
# <SimpleNet.SoftmaxLayer object at 0x110b3fd30>
# [[  4.94244264   1.51564305  -6.70893652]
#  [  6.56875516   4.22593702 -10.79066501]
#  [-10.13909235  -2.20445568  13.45765555]
#  [ -7.26362774  -1.64941554   8.97613102]]

# %%
plt.plot(net.train_log[::10])
